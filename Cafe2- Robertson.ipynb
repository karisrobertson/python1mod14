# %%
def expresso_charge(quantity):
    ExSubtotal= 1.50 * {quan_ex}
    return ExSubtotal


main_menu=["Coffee", "Tea", "Pastries"]

coffee_list= [["Expresso:", 1.50],["Americano:", 2.00],["Caffe Latte:", 2.25],["Mocha:", 2.25],["Cappucino:",2.50],["Macchiato:",2.50]]
coffee_selection= {"EX": 1.50, "AM": 2.00,"CA": 2.25, "MO": 2.25, "CO":2.5, "MA":2.50 }
#codeEX= "EX"
#codeAM= "AM"
#codeCA= "Caffee Latte"
#codeMO= "Mocha"
#codeCO= "Cappucino"
#codeMA= "Macchiato"


tea_list= [["White Tea:", 1.50],["Green Tea:", 2.00],["Oolong Tea:", 2.25], ["Black Tea:", 2.25], ["Earl Grey:", 2.25],["Matcha:",2.50]]
tea_selection= {"WT": 1.50, "GT":2.00, "OT": 2.25, "BT": 2.25, "EG":2.25, "MA": 2.50 }
codeWT= "WT"
codeGT= "GT"
codeOT= "OT"
codeBT= "BT"
codeEG= "EG"
codeMA= "MA"


pastry_list=[["Croissant:", 5.50], ["Cinnamon Roll:", 4.50], ["Bannana Bread:", 4.25], ["Pumpkin Bread:", 3.75], ["Sticky Bun:", 4.25], ["Apple Turnover:", 3.75]]
pastry_selection={"CR":5.50, "CI":4.50, "BB":4.25, "PB":3.75, "SB":4.25, "AT":3.75}
codeCR= "CR"
codeCI= "CI"
codeBB= "BB"
codePB= "PB"
codeSB= "SB"
codeAT= "AT"

# %%
print("Welcome to MC Cafe")
selection= int(input("Which Menu would you like to see? \nEnter: 0 for Coffee, 1 for Tea, or 2 for Pastries"))

my_order=[]
runningtotal=0 #subtotal
tax= .06
grand_total=runningtotal*tax



if selection == 0:
    print(coffee_list)
    user_coffee_choice= input("Please select your coffee choice by entering:\n EX for Expresso\n AM for Americano\n CA for Caffee Latte\n MO for Mocha\n CO for Cappucino\n MA for Macchiato")
    user_coffee_choice= user_coffee_choice.upper()

    for key in coffee_selection.items(): #iterating through dictionary
    
        user_selection = "n"
    while True:

        if user_coffee_choice == coffee_selection["EX"]: 
            if codeEX in coffee_selection:
                quan_ex= int(input("Please enter quantity of Expresso"))
                my_order.append(coffee_list[0]* quan_ex)
                expressoSubTotal= quan_ex * coffee_selection["EX"]
                expressoSubTotal+=runningtotal   
        
            user_selection = input("Would you like to check out y/n")
            if user_selection == "y":
                #print(coffee_list[0]* quan_ex) #prints your order
                print(f"Order: {my_order} Subtotal is: {runningtotal}\n Tax: {tax}\n Total: {grand_total}") 
break 
            else:
                user_selection == "n"
continue 
            
             
        
if user_coffee_choice == codeAM :
            if codeAM in coffee_selection:
                quan_am= int(input("Please enter quantity of Americano"))
                americanoSubTotal= quan_am * 2.00
                americanoSubTotal+=runningtotal
            
                user_selection = input("Would you like to check out y/n")
            if user_selection == "n":
                continue
            else:
                break 
            print(coffee_list[1] * quan_am)
            print (runningtotal)
    
if user_coffee_choice == codeCA:
        if codeCA in coffee_selection:
            quan_ca= int(input("Please enter quantity of Caffe Latte"))
            caffelatteSubTotal= quan_ca * 2.25
            runningtotal.append(caffelatteSubTotal)
            
if user_coffee_choice == codeMO:
        if codeMO in coffee_selection:
            quan_mo= int(input("Please enter quantity of Mocha"))
            mochaSubTotal= quan_mo * 2.25
            runningtotal.append(mochaSubTotal)
    
if user_coffee_choice == codeCO:
        if codeCO in coffee_selection:
            quan_co= int(input("Please enter quantity of Cappucino"))
            cappucinoSubTotal= quan_co * 2.50
            runningtotal.append(cappucinoSubTotal)
    
if user_coffee_choice == codeMA:
        if codeMA in coffee_selection:
            quan_ma= int(input("Please enter quantity of Macchiato"))
            macchiatoSubTotal= quan_ma * 2.50
            runningtotal.append(macchiatoSubTotal)
                         
                             
            
#continue and break statements -- yes should exit the loop and n should continue loop    
    
    
if selection == 1:
    print(tea_list)
    user_tea_choice= input("Please select your tea choice by entering:\n WT for White Tea\n GT for Green Tea\n OT for Oolong Tea\n BT for Black Tea\n EG for Earl Grey\n MA for Matcha")
    user_tea_choice= user_tea_choice.upper()


    
    



if selection == 2:
    print(pastry_list)
    user_pastry_choice= input("Please select your pastry choice by entering:\n CR for Croissant\n CI for Cinnamon Roll\n BB for Banana Bread\n PB for Pumpkin Bread\n SB for Sticky Bun\n AT for Apple Turnover")
    user_pastry_choice= user_pastry_choice.upper()
    
   
    print("Thank you for visiting MC cafe!")
